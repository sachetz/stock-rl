# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Import Dataset
#
# They need to be ordered by ascending date. Index must be DatetimeIndex. The DataFrame needs to contain a close price labelled close for the environment to run, and open, high, low, volume features respectively labelled open, high, low, volume to perform renders.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ClementPerroud/Gym-Trading-Env/main/examples/data/BTC_USD-Hourly.csv"
df = pd.read_csv(url, parse_dates=["date"], index_col= "date")
df.sort_index(inplace= True)
df.dropna(inplace= True)
df.drop_duplicates(inplace=True)
df
# Out:
#                            unix   symbol      open      high       low  \
# date
# 2018-05-15 06:00:00  1526364000  BTC/USD   8733.86   8796.68   8707.28
# 2018-05-15 07:00:00  1526367600  BTC/USD   8740.99   8766.00   8721.11
# 2018-05-15 08:00:00  1526371200  BTC/USD   8739.00   8750.27   8660.53
# 2018-05-15 09:00:00  1526374800  BTC/USD   8728.49   8754.40   8701.35
# 2018-05-15 10:00:00  1526378400  BTC/USD   8708.32   8865.00   8695.11
# ...                         ...      ...       ...       ...       ...
# 2022-02-28 20:00:00  1646078400  BTC/USD  41361.99  41971.00  41284.11
# 2022-02-28 21:00:00  1646082000  BTC/USD  41917.09  41917.09  41542.60
# 2022-02-28 22:00:00  1646085600  BTC/USD  41657.23  44256.08  41650.29
# 2022-02-28 23:00:00  1646089200  BTC/USD  43085.30  43364.81  42892.37
# 2022-03-01 00:00:00  1646092800  BTC/USD  43221.71  43626.49  43185.48
#
#                         close        volume    Volume USD
# date
# 2018-05-15 06:00:00   8740.99  4.906603e+06  5.599300e+02
# 2018-05-15 07:00:00   8739.00  2.390399e+06  2.735800e+02
# 2018-05-15 08:00:00   8728.49  7.986063e+06  9.177900e+02
# 2018-05-15 09:00:00   8708.32  1.593992e+06  1.826200e+02
# 2018-05-15 10:00:00   8795.90  1.110127e+07  1.260690e+03
# ...                       ...           ...           ...
# 2022-02-28 20:00:00  41914.97  2.471517e+02  1.035935e+07
# 2022-02-28 21:00:00  41659.53  6.975168e+01  2.905822e+06
# 2022-02-28 22:00:00  42907.32  5.275406e+02  2.263535e+07
# 2022-02-28 23:00:00  43178.98  1.068161e+02  4.612210e+06
# 2022-03-01 00:00:00  43312.27  5.205632e+01  2.254677e+06
#
# [33259 rows x 8 columns]

# %% [markdown]
# ## Built-in Downloader
#
# The packaging also include an easy way to download historical data of crypto pairs. It stores data as .pkl for easy and fast usage.

# %%
from gym_trading_env.downloader import download
import datetime
import pandas as pd

# Download BTC/USDT historical data from Binance and stores it to directory ./data/binance-BTCUSDT-1h.pkl
# download(exchange_names = ["bitfinex2"],
#     symbols= ["BTC/USDT", "ETH/USDT"],
#     timeframe= "1h",
#     dir = "data",
#     since= datetime.datetime(year= 2020, month= 1, day=1),
# )
# Import your fresh data
df = pd.read_pickle("./data/bitfinex2-BTCUSDT-1h.pkl")
df
# Out:
# BTC/USDT downloaded from bitfinex2 and stored at data/bitfinex2-BTCUSDT-1h.pkl
# ETH/USDT downloaded from bitfinex2 and stored at data/bitfinex2-ETHUSDT-1h.pkl
#                         open     high      low    close     volume  \
# date_open
# 2020-01-01 07:00:00   7231.7   7232.7   7205.2   7205.2   2.868045
# 2020-01-01 08:00:00   7209.7   7209.7   7189.5   7191.4  14.310214
# 2020-01-01 09:00:00   7207.8   7207.8   7197.4   7197.4   3.204737
# 2020-01-01 10:00:00   7191.6   7204.7   7191.6   7203.2   0.160143
# 2020-01-01 11:00:00   7205.6   7232.6   7191.2   7191.2   9.342426
# ...                      ...      ...      ...      ...        ...
# 2024-11-05 19:00:00  70243.0  70270.0  68734.0  69056.0  39.386788
# 2024-11-05 20:00:00  68997.0  69634.0  68854.0  69459.0  48.751650
# 2024-11-05 21:00:00  69460.0  69572.0  69081.0  69140.0  10.132064
# 2024-11-05 22:00:00  69210.0  69600.0  68887.0  69600.0  11.146974
# 2024-11-05 23:00:00  69533.0  69894.0  69320.0  69347.0   4.911178
#
#                              date_close
# date_open
# 2020-01-01 07:00:00 2020-01-01 08:00:00
# 2020-01-01 08:00:00 2020-01-01 09:00:00
# 2020-01-01 09:00:00 2020-01-01 10:00:00
# 2020-01-01 10:00:00 2020-01-01 11:00:00
# 2020-01-01 11:00:00 2020-01-01 12:00:00
# ...                                 ...
# 2024-11-05 19:00:00 2024-11-05 20:00:00
# 2024-11-05 20:00:00 2024-11-05 21:00:00
# 2024-11-05 21:00:00 2024-11-05 22:00:00
# 2024-11-05 22:00:00 2024-11-05 23:00:00
# 2024-11-05 23:00:00 2024-11-06 00:00:00
#
# [42462 rows x 6 columns]

# %% [markdown]
# # Creating Features
#
# The environment will recognize as inputs every column that contains the keyword 'feature' in its name.

# %% [markdown]
# ## Static Features

# %%
def preprocess(df : pd.DataFrame):
    df["feature_close"] = df["close"].pct_change()
    df["feature_open"] = df["open"]/df["close"]
    df["feature_high"] = df["high"]/df["close"]
    df["feature_low"] = df["low"]/df["close"]
    df["feature_volume"] = df["volume"] / df["volume"].rolling(7*24).max()
    df.dropna(inplace= True)
    return df

# %% [markdown]
# ## Dynamic Features

# %%
def dynamic_feature_last_position_taken(history):
    return history['position', -1]

def dynamic_feature_real_position(history):
    return history['real_position', -1]

# %% [markdown]
# # Creating Environment

# %% [markdown]
# History object stores many training information at each timestep of the training.
# - Stores training info like : step, date, reward, position ...
# - Gathers info from the initial DataFrame and labels them with data_{column_name} like: data_close, data_open, data_high ...
# - Stores the portfolio valuation and distribution
#
# Accessing data:
# - `history['column name', t]` returns a scalar value of the metrics ‘column name’ at time step t.
# - `history['column name']` returns a numpy array with all the values from timestep 0 to current timestep.
# - `history[t]` returns a dictionary with of the metrics as keys with the associated values.

# %% [markdown]
# ## Custom Reward Function
#
# The default reward function, where $p_t$ is portfolio valuation at timestep $t$, is:
# $$ r_t = \ln \frac{p_t}{p_{t-1}} $$

# %%
import gymnasium as gym
import numpy as np
def reward_function(history):
        return np.log(history["portfolio_valuation", -1] / history["portfolio_valuation", -2])

# %%
from gymnasium.envs.registration import register

register(
    id='MultiDatasetTradingEnvFixed',
    entry_point='multi_dataset_trading_env_fixed:MultiDatasetTradingEnvFixed',
    disable_env_checker = True
)

# %%
import gymnasium as gym

env = gym.make("MultiDatasetTradingEnvFixed",
        name= "BTC/ETH",
        dataset_dir= 'data/*.pkl',
        preprocess= preprocess,
        positions = [ -1, 0, 1], # -1 (=SHORT), 0(=OUT), +1 (=LONG)
        trading_fees = 0.01/100, # 0.01% per stock buy / sell (Binance fees)
        borrow_interest_rate= 0.0003/100, # 0.0003% per timestep (one timestep = 1h here),
        reward_function = reward_function,
        dynamic_feature_functions = [dynamic_feature_last_position_taken, dynamic_feature_real_position],
    )

# %% [markdown]
# ## Custom Logs/Metrics

# %% [markdown]
# The .add_metric method takes 2 parameters:
# - name: The displayed name of the metrics
# - function: The function that takes the History object as parameters and returns a value (prefer string over other types to avoid error).

# %%
env.unwrapped.add_metric('Position Changes', lambda history : np.sum(np.diff(history['position']) != 0) )
env.unwrapped.add_metric('Episode Length', lambda history : len(history['position']) )

# %% [markdown]
# # Running Environment

# %%
for _ in range(100):
    # Run an episode until it ends:
    done, truncated = False, False
    observation, info = env.reset()
    while not done and not truncated:
        # Pick a position by its index in your position list (=[-1, 0, 1])....usually something like : position_index = your_policy(observation)
        position_index = env.action_space.sample() # At every timestep, pick a random position index from your position list (=[-1, 0, 1])
        observation, reward, done, truncated, info = env.step(position_index)
# Out:
# Market Return : 732.34%   |   Portfolio Return : -98.82%   |   Position Changes : 28398   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -93.75%   |   Position Changes : 28084   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -90.02%   |   Position Changes : 28187   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.19%   |   Position Changes : 28405   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.81%   |   Position Changes : 28068   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.74%   |   Position Changes : 28056   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.82%   |   Position Changes : 28184   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.16%   |   Position Changes : 27962   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.42%   |   Position Changes : 28342   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.70%   |   Position Changes : 28177   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.64%   |   Position Changes : 28168   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.39%   |   Position Changes : 28248   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.78%   |   Position Changes : 28040   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.58%   |   Position Changes : 28148   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.32%   |   Position Changes : 28249   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.55%   |   Position Changes : 28252   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.40%   |   Position Changes : 28203   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -94.42%   |   Position Changes : 28171   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -74.93%   |   Position Changes : 28202   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.65%   |   Position Changes : 28087   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.52%   |   Position Changes : 28184   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.32%   |   Position Changes : 28423   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.93%   |   Position Changes : 28174   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.78%   |   Position Changes : 28199   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.50%   |   Position Changes : 28198   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.80%   |   Position Changes : 27967   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.72%   |   Position Changes : 28377   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -94.89%   |   Position Changes : 28285   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.82%   |   Position Changes : 28226   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -95.40%   |   Position Changes : 28329   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.89%   |   Position Changes : 28099   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.74%   |   Position Changes : 28376   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.54%   |   Position Changes : 28056   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -95.88%   |   Position Changes : 28218   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -92.06%   |   Position Changes : 28173   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.74%   |   Position Changes : 28214   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.74%   |   Position Changes : 28232   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.14%   |   Position Changes : 28212   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -94.73%   |   Position Changes : 28229   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.78%   |   Position Changes : 28092   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.43%   |   Position Changes : 28270   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.06%   |   Position Changes : 28162   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.95%   |   Position Changes : 28185   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.93%   |   Position Changes : 28026   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.05%   |   Position Changes : 27999   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.55%   |   Position Changes : 28153   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.76%   |   Position Changes : 28188   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.83%   |   Position Changes : 28293   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.84%   |   Position Changes : 28296   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.64%   |   Position Changes : 28425   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.47%   |   Position Changes : 28039   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.08%   |   Position Changes : 28257   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.88%   |   Position Changes : 28074   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.37%   |   Position Changes : 28285   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -92.29%   |   Position Changes : 28095   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.52%   |   Position Changes : 28357   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.91%   |   Position Changes : 28257   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.56%   |   Position Changes : 28044   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.48%   |   Position Changes : 27987   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.83%   |   Position Changes : 28235   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.80%   |   Position Changes : 28192   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.69%   |   Position Changes : 28131   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.29%   |   Position Changes : 28111   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.47%   |   Position Changes : 28088   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.62%   |   Position Changes : 28213   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.73%   |   Position Changes : 28311   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.93%   |   Position Changes : 28116   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.48%   |   Position Changes : 28227   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.82%   |   Position Changes : 28202   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.06%   |   Position Changes : 28149   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.80%   |   Position Changes : 28152   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.24%   |   Position Changes : 28086   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -88.60%   |   Position Changes : 28080   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.06%   |   Position Changes : 28262   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.40%   |   Position Changes : 28155   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -95.85%   |   Position Changes : 28114   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.77%   |   Position Changes : 28192   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.59%   |   Position Changes : 28303   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.12%   |   Position Changes : 27948   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -91.78%   |   Position Changes : 28151   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.76%   |   Position Changes : 28404   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.40%   |   Position Changes : 28018   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.37%   |   Position Changes : 28357   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.26%   |   Position Changes : 28132   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -90.96%   |   Position Changes : 28235   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.65%   |   Position Changes : 28280   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.39%   |   Position Changes : 28160   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.70%   |   Position Changes : 28008   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.54%   |   Position Changes : 28182   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.80%   |   Position Changes : 28233   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.52%   |   Position Changes : 28314   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.61%   |   Position Changes : 28184   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.56%   |   Position Changes : 28185   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.17%   |   Position Changes : 28176   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.88%   |   Position Changes : 28195   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -93.20%   |   Position Changes : 28172   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.19%   |   Position Changes : 28165   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.32%   |   Position Changes : 28130   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -91.42%   |   Position Changes : 28088   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.57%   |   Position Changes : 28237   |   Episode Length : 42295   |
