# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Import Dataset
#
# They need to be ordered by ascending date. Index must be DatetimeIndex. The DataFrame needs to contain a close price labelled close for the environment to run, and open, high, low, volume features respectively labelled open, high, low, volume to perform renders.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ClementPerroud/Gym-Trading-Env/main/examples/data/BTC_USD-Hourly.csv"
df = pd.read_csv(url, parse_dates=["date"], index_col= "date")
df.sort_index(inplace= True)
df.dropna(inplace= True)
df.drop_duplicates(inplace=True)
df
# Out:
#                            unix   symbol      open      high       low  \
# date
# 2018-05-15 06:00:00  1526364000  BTC/USD   8733.86   8796.68   8707.28
# 2018-05-15 07:00:00  1526367600  BTC/USD   8740.99   8766.00   8721.11
# 2018-05-15 08:00:00  1526371200  BTC/USD   8739.00   8750.27   8660.53
# 2018-05-15 09:00:00  1526374800  BTC/USD   8728.49   8754.40   8701.35
# 2018-05-15 10:00:00  1526378400  BTC/USD   8708.32   8865.00   8695.11
# ...                         ...      ...       ...       ...       ...
# 2022-02-28 20:00:00  1646078400  BTC/USD  41361.99  41971.00  41284.11
# 2022-02-28 21:00:00  1646082000  BTC/USD  41917.09  41917.09  41542.60
# 2022-02-28 22:00:00  1646085600  BTC/USD  41657.23  44256.08  41650.29
# 2022-02-28 23:00:00  1646089200  BTC/USD  43085.30  43364.81  42892.37
# 2022-03-01 00:00:00  1646092800  BTC/USD  43221.71  43626.49  43185.48
#
#                         close        volume    Volume USD
# date
# 2018-05-15 06:00:00   8740.99  4.906603e+06  5.599300e+02
# 2018-05-15 07:00:00   8739.00  2.390399e+06  2.735800e+02
# 2018-05-15 08:00:00   8728.49  7.986063e+06  9.177900e+02
# 2018-05-15 09:00:00   8708.32  1.593992e+06  1.826200e+02
# 2018-05-15 10:00:00   8795.90  1.110127e+07  1.260690e+03
# ...                       ...           ...           ...
# 2022-02-28 20:00:00  41914.97  2.471517e+02  1.035935e+07
# 2022-02-28 21:00:00  41659.53  6.975168e+01  2.905822e+06
# 2022-02-28 22:00:00  42907.32  5.275406e+02  2.263535e+07
# 2022-02-28 23:00:00  43178.98  1.068161e+02  4.612210e+06
# 2022-03-01 00:00:00  43312.27  5.205632e+01  2.254677e+06
#
# [33259 rows x 8 columns]

# %% [markdown]
# ## Built-in Downloader
#
# The packaging also include an easy way to download historical data of crypto pairs. It stores data as .pkl for easy and fast usage.

# %%
from gym_trading_env.downloader import download
import datetime
import pandas as pd

# Download BTC/USDT historical data from Binance and stores it to directory ./data/binance-BTCUSDT-1h.pkl
# download(exchange_names = ["bitfinex2"],
#     symbols= ["BTC/USDT", "ETH/USDT"],
#     timeframe= "1h",
#     dir = "data",
#     since= datetime.datetime(year= 2020, month= 1, day=1),
# )
# Import your fresh data
df = pd.read_pickle("./data/bitfinex2-BTCUSDT-1h.pkl")
df
# Out:
#                         open     high      low    close     volume  \
# date_open
# 2020-01-01 07:00:00   7231.7   7232.7   7205.2   7205.2   2.868045
# 2020-01-01 08:00:00   7209.7   7209.7   7189.5   7191.4  14.310214
# 2020-01-01 09:00:00   7207.8   7207.8   7197.4   7197.4   3.204737
# 2020-01-01 10:00:00   7191.6   7204.7   7191.6   7203.2   0.160143
# 2020-01-01 11:00:00   7205.6   7232.6   7191.2   7191.2   9.342426
# ...                      ...      ...      ...      ...        ...
# 2024-11-05 19:00:00  70243.0  70270.0  68734.0  69056.0  39.386788
# 2024-11-05 20:00:00  68997.0  69634.0  68854.0  69459.0  48.751650
# 2024-11-05 21:00:00  69460.0  69572.0  69081.0  69140.0  10.132064
# 2024-11-05 22:00:00  69210.0  69600.0  68887.0  69600.0  11.146974
# 2024-11-05 23:00:00  69533.0  69894.0  69320.0  69347.0   4.911178
#
#                              date_close
# date_open
# 2020-01-01 07:00:00 2020-01-01 08:00:00
# 2020-01-01 08:00:00 2020-01-01 09:00:00
# 2020-01-01 09:00:00 2020-01-01 10:00:00
# 2020-01-01 10:00:00 2020-01-01 11:00:00
# 2020-01-01 11:00:00 2020-01-01 12:00:00
# ...                                 ...
# 2024-11-05 19:00:00 2024-11-05 20:00:00
# 2024-11-05 20:00:00 2024-11-05 21:00:00
# 2024-11-05 21:00:00 2024-11-05 22:00:00
# 2024-11-05 22:00:00 2024-11-05 23:00:00
# 2024-11-05 23:00:00 2024-11-06 00:00:00
#
# [42462 rows x 6 columns]

# %% [markdown]
# # Creating Features
#
# The environment will recognize as inputs every column that contains the keyword 'feature' in its name.

# %% [markdown]
# ## Static Features

# %%
def preprocess(df : pd.DataFrame):
    df["feature_close"] = df["close"].pct_change()
    df["feature_open"] = df["open"]/df["close"]
    df["feature_high"] = df["high"]/df["close"]
    df["feature_low"] = df["low"]/df["close"]
    df["feature_volume"] = df["volume"] / df["volume"].rolling(7*24).max()
    df.dropna(inplace= True)
    return df

# %% [markdown]
# ## Dynamic Features

# %%
def dynamic_feature_last_position_taken(history):
    return history['position', -1]

def dynamic_feature_real_position(history):
    return history['real_position', -1]

# %% [markdown]
# # Creating Environment

# %% [markdown]
# History object stores many training information at each timestep of the training.
# - Stores training info like : step, date, reward, position ...
# - Gathers info from the initial DataFrame and labels them with data_{column_name} like: data_close, data_open, data_high ...
# - Stores the portfolio valuation and distribution
#
# Accessing data:
# - `history['column name', t]` returns a scalar value of the metrics ‘column name’ at time step t.
# - `history['column name']` returns a numpy array with all the values from timestep 0 to current timestep.
# - `history[t]` returns a dictionary with of the metrics as keys with the associated values.

# %% [markdown]
# ## Custom Reward Function
#
# The default reward function, where $p_t$ is portfolio valuation at timestep $t$, is:
# $$ r_t = \ln \frac{p_t}{p_{t-1}} $$

# %%
import gymnasium as gym
import numpy as np
def reward_function(history):
        return np.log(history["portfolio_valuation", -1] / history["portfolio_valuation", -2])

# %%
from gymnasium.envs.registration import register

register(
    id='MultiDatasetTradingEnvFixed',
    entry_point='multi_dataset_trading_env_fixed:MultiDatasetTradingEnvFixed',
    disable_env_checker = True
)

# %%
from metrics import position_changes, episode_length

envs = gym.make_vec("MultiDatasetTradingEnvFixed", num_envs=2, vectorization_mode="async",
            dataset_dir= 'data/*.pkl',
            preprocess= preprocess,
            positions = [ -1, 0, 1], # -1 (=SHORT), 0(=OUT), +1 (=LONG)
            trading_fees = 0.01/100, # 0.01% per stock buy / sell (Binance fees)
            borrow_interest_rate= 0.0003/100, # 0.0003% per timestep (one timestep = 1h here),
            reward_function = reward_function,
            dynamic_feature_functions = [dynamic_feature_last_position_taken, dynamic_feature_real_position])

envs.call("add_metric", "Position Changes", position_changes)
envs.call("add_metric", "Episode Length", episode_length)
# Out:
# (None, None)

# %% [markdown]
# ## Custom Logs/Metrics

# %% [markdown]
# The .add_metric method takes 2 parameters:
# - name: The displayed name of the metrics
# - function: The function that takes the History object as parameters and returns a value (prefer string over other types to avoid error).

# %%
# env.unwrapped.add_metric('Position Changes', lambda history : np.sum(np.diff(history['position']) != 0) )
# env.unwrapped.add_metric('Episode Length', lambda history : len(history['position']) )

# %% [markdown]
# # Running Environment

# %%
for _ in range(10):
    # Run an episode until all environments are done or truncated
    done = np.array([False] * envs.num_envs)
    truncated = np.array([False] * envs.num_envs)
    observation, info = envs.reset()
    
    while not done.all() and not truncated.all():
        # Pick random positions for each environment
        position_index = envs.action_space.sample()
        
        # Take a step in all environments with the selected actions
        observation, reward, done, truncated, info = envs.step(position_index)
# Out:
# Market Return : 732.34%   |   Portfolio Return : -98.05%   |   Position Changes : 28269   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.21%   |   Position Changes : 28280   |   Episode Length : 42295   |
# Market Return : 1569.56%   |   Portfolio Return : -98.63%   |   Position Changes : 28146   |   Episode Length : 42286   |
# Market Return : 1569.56%   |   Portfolio Return : -99.13%   |   Position Changes : 28387   |   Episode Length : 42286   |
# Market Return : 732.34%   |   Portfolio Return : -99.69%   |   Position Changes : 28021   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.63%   |   Position Changes : 28193   |   Episode Length : 42295   |
# Market Return : 1569.56%   |   Portfolio Return : -99.54%   |   Position Changes : 28283   |   Episode Length : 42286   |
# Market Return : 732.34%   |   Portfolio Return : -99.49%   |   Position Changes : 28194   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.81%   |   Position Changes : 28316   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.57%   |   Position Changes : 28054   |   Episode Length : 42295   |
# Market Return : 1569.56%   |   Portfolio Return : -91.15%   |   Position Changes : 28099   |   Episode Length : 42286   |
# Market Return : 732.34%   |   Portfolio Return : -98.23%   |   Position Changes : 28035   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.84%   |   Position Changes : 28420   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -78.43%   |   Position Changes : 28179   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -96.66%   |   Position Changes : 28143   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.21%   |   Position Changes : 28144   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.61%   |   Position Changes : 28285   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.41%   |   Position Changes : 28133   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.78%   |   Position Changes : 28106   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.87%   |   Position Changes : 28181   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -94.74%   |   Position Changes : 28257   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.77%   |   Position Changes : 28217   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.60%   |   Position Changes : 28153   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.34%   |   Position Changes : 28149   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.73%   |   Position Changes : 28199   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.07%   |   Position Changes : 28128   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.62%   |   Position Changes : 28067   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.81%   |   Position Changes : 28235   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.22%   |   Position Changes : 28100   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.16%   |   Position Changes : 28169   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.39%   |   Position Changes : 28147   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.06%   |   Position Changes : 28344   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.55%   |   Position Changes : 28288   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.43%   |   Position Changes : 28218   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.66%   |   Position Changes : 28317   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.94%   |   Position Changes : 28135   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.51%   |   Position Changes : 28185   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.85%   |   Position Changes : 28292   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.11%   |   Position Changes : 28327   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.60%   |   Position Changes : 28109   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -88.71%   |   Position Changes : 28205   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.64%   |   Position Changes : 28179   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -92.55%   |   Position Changes : 28145   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.18%   |   Position Changes : 28105   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.63%   |   Position Changes : 28177   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.50%   |   Position Changes : 28128   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.73%   |   Position Changes : 28290   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -91.54%   |   Position Changes : 28075   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.27%   |   Position Changes : 28324   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.86%   |   Position Changes : 28286   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -89.52%   |   Position Changes : 28057   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.53%   |   Position Changes : 28178   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.41%   |   Position Changes : 28223   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.05%   |   Position Changes : 28412   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.93%   |   Position Changes : 28221   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.40%   |   Position Changes : 28070   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -94.88%   |   Position Changes : 28153   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.65%   |   Position Changes : 28150   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.39%   |   Position Changes : 28048   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.91%   |   Position Changes : 28142   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.16%   |   Position Changes : 28366   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.07%   |   Position Changes : 27988   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.30%   |   Position Changes : 28390   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.03%   |   Position Changes : 28088   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.67%   |   Position Changes : 28259   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.11%   |   Position Changes : 28190   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.15%   |   Position Changes : 28039   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.73%   |   Position Changes : 28343   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.97%   |   Position Changes : 28164   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -97.19%   |   Position Changes : 28381   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.77%   |   Position Changes : 28022   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -99.38%   |   Position Changes : 28240   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.26%   |   Position Changes : 28298   |   Episode Length : 42295   |
# Market Return : 732.34%   |   Portfolio Return : -98.72%   |   Position Changes : 28154   |   Episode Length : 42295   |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#       9 position_index = envs.action_space.sample()
#      11 # Take a step in all environments with the selected actions
# ---> 12 observation, reward, done, truncated, info = envs.step(position_index)
#
# File ~/uchicago_mpcs/adv_data_analytics/stock-rl/.venv/lib/python3.12/site-packages/gymnasium/vector/async_vector_env.py:353, in AsyncVectorEnv.step(self, actions)
#     344 """Take an action for each parallel environment.
#     345
#     346 Args:
#    (...)
#     350     Batch of (observations, rewards, terminations, truncations, infos)
#     351 """
#     352 self.step_async(actions)
# --> 353 return self.step_wait()
#
# File ~/uchicago_mpcs/adv_data_analytics/stock-rl/.venv/lib/python3.12/site-packages/gymnasium/vector/async_vector_env.py:411, in AsyncVectorEnv.step_wait(self, timeout)
#     409 observations, rewards, terminations, truncations, infos = [], [], [], [], {}
#     410 successes = []
# --> 411 for env_idx, pipe in enumerate(self.parent_pipes):
#     412     env_step_return, success = pipe.recv()
#     414     successes.append(success)
#
# KeyboardInterrupt:
